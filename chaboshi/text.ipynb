# %%
import json
import requests

def getProxy():
    s = requests.session()
    s.keep_alive = False
    url = 'http://120.27.216.150:5000'
    headers = {
        'Connection': 'close',
    }
    proxy = s.get(url=url, headers=headers, auth=('admin', 'zd123456')).text[0:-6]
    return proxy

headers = {
    # 'User-Agent': 'app=2 versionCode=87',
    # 'PARTNER': 'e9b5849e97b44970bc9c63c62cd4382e',
    # 'LOCATION': '0,0',
    # 'TOKEN': '6A030696DD727975WxM9LDKNX0Exl3SRrUDkWg==',
    'Content-Type': 'application/x-www-form-urlencoded',
    # 'Content-Length': '699',
    # 'Host': 'app.chaboshi.cn',
    # 'Connection': 'Keep-Alive',
    # 'Accept-Encoding': 'gzip',
    # 'Cookie': 'CBS_UUID="NGFlMmZhZTBmZGYzNjVjYzY4MDRhNjgzNjQ1MDAyZGUsNzIwLDE1OTk3Mjc3OTY1NDc="; JSESSIONID=00DE3FEE055F8C842AD3D3D1B0ADA87A'
}
proxy = {'http': getProxy()}

# %%
brand_url = 'https://app.chaboshi.cn/app/brandModel/getBrands'
brand_post_data = ''
brand_html = requests.post(url=brand_url)
print(brand_html.content.decode('utf-8'))
# Out:
# {"code":0,"data":{"data":[{"brandName":"爱驰汽车","brandNamePinyin":"AICHIQICHE","id":378},{"brandName":"安驰","brandNamePinyin":"ANCHI","id":393,"logoLight":"210b29f178c54f2cb4c9bf57e199452c"},{"brandName":"奥迪","brandNamePinyin":"AODI","id":414,"logoLight":"02d16a18322e42cb83844c18118ea45f"},{"brandName":"阿斯顿·马丁","brandNamePinyin":"ASIDUNMADING","id":457,"logoLight":"515e46a8bc4c44559962ed09c068bd8b"},{"brandName":"AC Schnitzer","brandNamePinyin":"AC SCHNITZER","id":520},{"brandName":"奥克斯","brandNamePinyin":"AOKESI","id":550,"logoLight":"9c72a00b3a184ef69fa33224e142f388"},{"brandName":"阿尔法·罗密欧","brandNamePinyin":"AERFALUOMIOU","id":559,"logoLight":"a93f7f5522ce4f7c9d3cc81261b961a1"},{"brandName":"ALPINA","brandNamePinyin":"ALPINA","id":595},{"brandName":"北汽威旺","brandNamePinyin":"BEIQIWEIWANG","id":387,"logoLight":"207480ab7e744643b84cdda6111328bb"},{"brandName":"北汽皮卡","brandNamePinyin":"BEIQIPIKA","id":389},{"brandName":"比亚迪","brandNamePinyin":"BIYADI","id":402,"logoLight":"c70556ea101948
# ...

# %%
family_url = ' https://app.chaboshi.cn/app/brandModel/getSeries'
family_post_data = 'supportbrandid=414'
family_html = requests.post(url=family_url,data=family_post_data,headers=headers,proxies=proxy)
print(family_html.content.decode('utf-8'))
# Out:
# {"code":0,"data":{"data":{"奥迪RS":[{"brand58Id":408844,"image":"fa8309e21be24e13a96213d62a20e1bb","supportBrandId":414,"addTime":1589802553000,"updateTime":1589803336000,"source":1,"series58Id":800481,"manufacturer":"奥迪RS","isJc":true,"deleted":false,"series":"奥迪RS 7","brandId":414,"id":7118,"seriesVersion":3,"valuable":true},{"brand58Id":408844,"supportBrandId":414,"addTime":1589802553000,"updateTime":1589803330000,"source":1,"imageLarge":"e129713ae6134bcfb998aa034d7582c1","series58Id":800483,"manufacturer":"奥迪RS","isJc":true,"deleted":false,"series":"奥迪RS 3","brandId":414,"id":7115,"seriesVersion":3,"valuable":true},{"brand58Id":408844,"supportBrandId":414,"addTime":1589802553000,"updateTime":1589803329000,"source":1,"series58Id":800485,"manufacturer":"奥迪RS","isJc":true,"deleted":false,"series":"奥迪RS 6","brandId":414,"id":7113,"seriesVersion":3,"valuable":true},{"brand58Id":408844,"image":"259752c13dd04084b6a8611a7071e339","supportBrandId":414,"addTime":1589802553000,"updateTime":15
# ...

# %%
vehicle_url = 'https://app.chaboshi.cn/app/brandModel/getModelsValuationAble'
vehicle_post_data = 'supportseriesid=9292'
vehicle_html = requests.post(url=vehicle_url,data=vehicle_post_data,headers=headers,proxies=proxy)
print(vehicle_html.content.decode('utf-8'))
# Out:
# {"code":1,"message":"该车系下暂无车型"}

# %%
token_url = 'https://app.chaboshi.cn/app/assess/freeSubmit'
token_post_data = 'carModelId=327335&drivedMiles=0.1&cityId=970&source=android&plateTime=2020-8'
token_html = requests.post(url=token_url,data=token_post_data,headers=headers,proxies=proxy)
print(token_html.content.decode('utf-8'))
token_json = json.loads(token_html.content.decode('utf-8'))
fakeOrderNo = token_json['data']['fakeOrderNo']
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\users\13164\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     661             if is_new_proxy_conn:
# --> 662                 self._prepare_proxy(conn)
#     663
#
# c:\users\13164\appdata\local\programs\python\python37\lib\site-packages\urllib3\connectionpool.py in _prepare_proxy(self, conn)
#     947         conn.set_tunnel(self._proxy_host, self.port, self.proxy_headers)
# --> 948         conn.connect()
#     949
#
# c:\users\13164\appdata\local\programs\python\python37\lib\site-packages\urllib3\connection.py in connect(self)
#     307             # self._tunnel_host below.
# --> 308             self._tunnel()
# ...

# %%
gz_url = f'https://app.chaboshi.cn/wap/getFreeAssessReport?fakeOrderNo={fakeOrderNo}'
gz_html = requests.get(url=gz_url,proxies=proxy)
print(gz_html.content.decode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-b58a24c936dd> in <module>
# ----> 1 gz_url = f'https://app.chaboshi.cn/wap/getFreeAssessReport?fakeOrderNo={fakeOrderNo}'
#       2 gz_html = requests.get(url=gz_url,proxies=proxy)
#       3 print(gz_html.content.decode('utf-8'))
#       4
#       5
#
# NameError: name 'fakeOrderNo' is not defined

# %%
city_codes = {"code":0,"data":{"city":[{"citys":[{"carNoHeader":"鲁A","city_id":859,"city_name":"济南","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁B","city_id":943,"city_name":"青岛","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁C","city_id":1063,"city_name":"淄博","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁D","city_id":1068,"city_name":"枣庄","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁E","city_id":776,"city_name":"东营","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁F","city_id":1050,"city_name":"烟台","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁G","city_id":1010,"city_name":"潍坊","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁H","city_id":862,"city_name":"济宁","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁J","city_id":977,"city_name":"泰安","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁K","city_id":1001,"city_name":"威海","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁L","city_id":945,"city_name":"日照","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁M","city_id":727,"city_name":"滨州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁N","city_id":782,"city_name":"德州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁P","city_id":900,"city_name":"聊城","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁Q","city_id":890,"city_name":"临沂","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁R","city_id":820,"city_name":"菏泽","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鲁S","city_id":886,"city_name":"莱芜","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Shandong","province":"山东"},{"citys":[{"city_id":2328,"city_name":"台湾","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Taiwan","province":"台湾"},{"citys":[{"carNoHeader":"闽A","city_id":792,"city_name":"福州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"闽B","city_id":927,"city_name":"莆田","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"闽C","city_id":929,"city_name":"泉州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"闽D","city_id":1029,"city_name":"厦门","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"闽E","city_id":1071,"city_name":"漳州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"闽F","city_id":894,"city_name":"龙岩","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"闽G","city_id":950,"city_name":"三明","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"闽H","city_id":916,"city_name":"南平","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"闽J","city_id":919,"city_name":"宁德","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Fujian","province":"福建"},{"citys":[{"carNoHeader":"冀A","city_id":952,"city_name":"石家庄","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"冀B","city_id":982,"city_name":"唐山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"冀C","city_id":936,"city_name":"秦皇岛","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"冀D","city_id":832,"city_name":"邯郸","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"冀E","city_id":1028,"city_name":"邢台","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"冀F","city_id":745,"city_name":"保定","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"冀G","city_id":1064,"city_name":"张家口","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"冀H","city_id":748,"city_name":"承德","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"冀J","city_id":754,"city_name":"沧州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"冀R","city_id":887,"city_name":"廊坊","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"冀T","city_id":835,"city_name":"衡水","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Hebei","province":"河北"},{"citys":[{"carNoHeader":"豫A","city_id":1073,"city_name":"郑州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫B","city_id":867,"city_name":"开封","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫C","city_id":895,"city_name":"洛阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫D","city_id":926,"city_name":"平顶山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫E","city_id":713,"city_name":"安阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫F ","city_id":815,"city_name":"鹤壁","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫G","city_id":1019,"city_name":"新乡","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫H","city_id":854,"city_name":"焦作","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫J","city_id":924,"city_name":"濮阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫K","city_id":1031,"city_name":"许昌","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫L","city_id":872,"city_name":"漯河","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫M","city_id":951,"city_name":"三门峡","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫N","city_id":957,"city_name":"商丘","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫P","city_id":1078,"city_name":"周口","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫Q","city_id":1081,"city_name":"驻马店","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫R","city_id":912,"city_name":"南阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫S","city_id":1024,"city_name":"信阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"豫U","city_id":845,"city_name":"济源","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Henan","province":"河南"},{"citys":[{"carNoHeader":"渝","city_id":746,"city_name":"重庆","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Chongqing","province":"重庆"},{"citys":[{"carNoHeader":"湘A","city_id":764,"city_name":"长沙","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"湘B","city_id":1062,"city_name":"株洲","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"湘C","city_id":1018,"city_name":"湘潭","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"湘D","city_id":823,"city_name":"衡阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"湘E","city_id":958,"city_name":"邵阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"湘F","city_id":1053,"city_name":"岳阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"湘G","city_id":1061,"city_name":"张家界","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"湘H","city_id":1039,"city_name":"益阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"湘J","city_id":762,"city_name":"常德","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"湘K","city_id":896,"city_name":"娄底","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"湘L","city_id":750,"city_name":"郴州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"湘M","city_id":1047,"city_name":"永州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"湘N","city_id":829,"city_name":"怀化","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"湘P","city_id":1033,"city_name":"湘西","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Hunan","province":"湖南"},{"citys":[{"carNoHeader":"鄂A","city_id":1002,"city_name":"武汉","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂B","city_id":824,"city_name":"黄石","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂C","city_id":960,"city_name":"十堰","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂D","city_id":857,"city_name":"荆州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂E","city_id":1059,"city_name":"宜昌","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂F","city_id":1014,"city_name":"襄阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂G","city_id":785,"city_name":"鄂州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂H","city_id":849,"city_name":"荆门","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂J","city_id":834,"city_name":"黄冈","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂K","city_id":1022,"city_name":"孝感","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂L","city_id":1030,"city_name":"咸宁","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂M","city_id":1016,"city_name":"仙桃","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂N","city_id":933,"city_name":"潜江","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂P","city_id":961,"city_name":"神农架林区","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂Q","city_id":787,"city_name":"恩施","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂R","city_id":981,"city_name":"天门","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"鄂S","city_id":974,"city_name":"随州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Hubei","province":"湖北"},{"citys":[{"carNoHeader":"琼A","city_id":816,"city_name":"海口","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼B","city_id":956,"city_name":"三亚","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼C","city_id":938,"city_name":"琼海","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼C","city_id":899,"city_name":"临高","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼C","city_id":1000,"city_name":"万宁","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼C","city_id":946,"city_name":"三沙","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼C","city_id":990,"city_name":"屯昌","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼C","city_id":996,"city_name":"文昌","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼C","city_id":756,"city_name":"澄迈","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼C","city_id":779,"city_name":"定安","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼D","city_id":941,"city_name":"琼中","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼D","city_id":884,"city_name":"乐东","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼D","city_id":1006,"city_name":"五指山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼D","city_id":888,"city_name":"陵水","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼D","city_id":742,"city_name":"保亭","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼D","city_id":726,"city_name":"白沙","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼D","city_id":749,"city_name":"昌江","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼D","city_id":774,"city_name":"东方","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"琼F","city_id":783,"city_name":"儋州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Hainan","province":"海南"},{"citys":[{"carNoHeader":"赣A","city_id":909,"city_name":"南昌","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"赣B","city_id":796,"city_name":"赣州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"赣C","city_id":1045,"city_name":"宜春","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"赣D","city_id":846,"city_name":"吉安","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"赣E","city_id":963,"city_name":"上饶","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"赣F","city_id":790,"city_name":"抚州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"赣G","city_id":853,"city_name":"九江","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"赣H","city_id":848,"city_name":"景德镇","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"赣J","city_id":922,"city_name":"萍乡","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"赣K","city_id":1025,"city_name":"新余","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"赣L","city_id":1058,"city_name":"鹰潭","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Jiangxi","province":"江西"},{"citys":[{"carNoHeader":"黑A","city_id":814,"city_name":"哈尔滨","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"黑B","city_id":930,"city_name":"齐齐哈尔","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"黑C","city_id":902,"city_name":"牡丹江","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"黑D","city_id":850,"city_name":"佳木斯","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"黑E","city_id":768,"city_name":"大庆","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"黑F","city_id":1040,"city_name":"伊春","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"黑G","city_id":861,"city_name":"鸡西","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"黑H","city_id":828,"city_name":"鹤岗","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"黑J","city_id":966,"city_name":"双鸭山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"黑K","city_id":937,"city_name":"七台河","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"黑M","city_id":973,"city_name":"绥化","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"黑N","city_id":836,"city_name":"黑河","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"黑P","city_id":770,"city_name":"大兴安岭","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Heilongjiang","province":"黑龙江"},{"citys":[{"carNoHeader":"津","city_id":989,"city_name":"天津","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Tianjin","province":"天津"},{"citys":[{"carNoHeader":"贵A","city_id":805,"city_name":"贵阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"贵B","city_id":870,"city_name":"六盘水","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"贵C","city_id":1065,"city_name":"遵义","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"贵D","city_id":985,"city_name":"铜仁","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"贵E","city_id":940,"city_name":"黔西南","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"贵F","city_id":738,"city_name":"毕节","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"贵G","city_id":717,"city_name":"安顺","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"贵H","city_id":942,"city_name":"黔东南","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"贵J","city_id":928,"city_name":"黔南","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Guizhou","province":"贵州"},{"citys":[{"carNoHeader":"陕A","city_id":1034,"city_name":"西安","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"陕B","city_id":978,"city_name":"铜川","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"陕C","city_id":732,"city_name":"宝鸡","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"陕D","city_id":1020,"city_name":"咸阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"陕E","city_id":1008,"city_name":"渭南","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"陕F","city_id":841,"city_name":"汉中","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"陕G","city_id":715,"city_name":"安康","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"陕H","city_id":955,"city_name":"商洛","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"陕J","city_id":1055,"city_name":"延安","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"陕K","city_id":1038,"city_name":"榆林","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Shaanxi","province":"陕西"},{"citys":[{"carNoHeader":"新A","city_id":1009,"city_name":"乌鲁木齐","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"新B","city_id":1003,"city_name":"五家渠","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"新C","city_id":972,"city_name":"石河子","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"新D,新F,新G,新H","city_id":1036,"city_name":"伊犁","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"新E","city_id":730,"city_name":"博尔塔拉","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"新J","city_id":868,"city_name":"克拉玛依","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"新K","city_id":986,"city_name":"吐鲁番","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"新L","city_id":808,"city_name":"哈密","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"新M","city_id":734,"city_name":"巴音郭楞","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"新N","city_id":712,"city_name":"阿拉尔","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"新P","city_id":865,"city_name":"克孜勒苏","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"新Q","city_id":980,"city_name":"图木舒克","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Xinjiang","province":"新疆"},{"citys":[{"carNoHeader":"粤Z","city_id":2343,"city_name":"澳门","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Macau","province":"澳门"},{"citys":[{"carNoHeader":"苏A","city_id":911,"city_name":"南京","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"苏B","city_id":1004,"city_name":"无锡","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"苏C","city_id":1023,"city_name":"徐州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"苏D","city_id":760,"city_name":"常州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"苏E","city_id":971,"city_name":"苏州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"苏F","city_id":908,"city_name":"南通","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"苏G","city_id":877,"city_name":"连云港","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"苏H","city_id":821,"city_name":"淮安","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"苏J","city_id":1048,"city_name":"盐城","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"苏K","city_id":1051,"city_name":"扬州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"苏L","city_id":1079,"city_name":"镇江","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"苏M","city_id":994,"city_name":"泰州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"苏N","city_id":949,"city_name":"宿迁","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Jiangsu","province":"江苏"},{"citys":[{"carNoHeader":"皖A","city_id":807,"city_name":"合肥","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"皖B","city_id":999,"city_name":"芜湖","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"皖C","city_id":733,"city_name":"蚌埠","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"皖D","city_id":826,"city_name":"淮南","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"皖E","city_id":905,"city_name":"马鞍山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"皖F","city_id":837,"city_name":"淮北","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"皖G","city_id":993,"city_name":"铜陵","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"皖H","city_id":714,"city_name":"安庆","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"皖J","city_id":817,"city_name":"黄山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"皖K","city_id":791,"city_name":"阜阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"皖L","city_id":968,"city_name":"宿州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"皖M","city_id":753,"city_name":"滁州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"皖N","city_id":875,"city_name":"六安","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"皖P","city_id":1021,"city_name":"宣城","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"皖R","city_id":751,"city_name":"池州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"皖S","city_id":729,"city_name":"亳州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Anhui","province":"安徽"},{"citys":[{"carNoHeader":"藏A","city_id":893,"city_name":"拉萨","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"藏B","city_id":747,"city_name":"昌都","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"藏C","city_id":953,"city_name":"山南","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"藏D","city_id":944,"city_name":"日喀则","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"藏E","city_id":918,"city_name":"那曲","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"藏F","city_id":720,"city_name":"阿里","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"藏G","city_id":889,"city_name":"林芝","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Tibet","province":"西藏"},{"citys":[{"carNoHeader":"吉A","city_id":761,"city_name":"长春","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"吉B","city_id":863,"city_name":"吉林","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"吉C","city_id":948,"city_name":"四平","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"吉D","city_id":879,"city_name":"辽源","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"吉E","city_id":984,"city_name":"通化","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"吉F","city_id":736,"city_name":"白山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"吉G","city_id":743,"city_name":"白城","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"吉H","city_id":1037,"city_name":"延边","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"吉J","city_id":969,"city_name":"松原","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Jilin","province":"吉林"},{"citys":[{"carNoHeader":"沪","city_id":970,"city_name":"上海","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Shanghai","province":"上海"},{"citys":[{"carNoHeader":"宁A","city_id":1057,"city_name":"银川","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"宁B","city_id":976,"city_name":"石嘴山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"宁C","city_id":997,"city_name":"吴忠","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"宁D","city_id":798,"city_name":"固原","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"宁E","city_id":1072,"city_name":"中卫","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Ningxia","province":"宁夏"},{"citys":[{"carNoHeader":"晋A","city_id":992,"city_name":"太原","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"晋B","city_id":769,"city_name":"大同","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"晋C","city_id":1042,"city_name":"阳泉","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"晋D","city_id":752,"city_name":"长治","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"晋E ","city_id":852,"city_name":"晋城","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"晋F","city_id":965,"city_name":"朔州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"晋H","city_id":1017,"city_name":"忻州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"晋J","city_id":885,"city_name":"吕梁","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"晋K","city_id":860,"city_name":"晋中","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"晋L","city_id":880,"city_name":"临汾","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"晋M","city_id":1035,"city_name":"运城","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Shanxi","province":"山西"},{"citys":[{"carNoHeader":"甘A","city_id":882,"city_name":"兰州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"甘B ","city_id":842,"city_name":"嘉峪关","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"甘C","city_id":851,"city_name":"金昌","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"甘D","city_id":740,"city_name":"白银","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"甘E","city_id":991,"city_name":"天水","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"甘F","city_id":856,"city_name":"酒泉","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"甘G","city_id":1069,"city_name":"张掖","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"甘H","city_id":998,"city_name":"武威","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"甘J","city_id":784,"city_name":"定西","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"甘K","city_id":876,"city_name":"陇南","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"甘L","city_id":923,"city_name":"平凉","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"甘M","city_id":939,"city_name":"庆阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"甘N","city_id":878,"city_name":"临夏","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"甘P","city_id":799,"city_name":"甘南","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Gansu","province":"甘肃"},{"citys":[{"carNoHeader":"粤Z","city_id":2327,"city_name":"香港","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Hong Kong","province":"香港"},{"citys":[{"carNoHeader":"川A","city_id":757,"city_name":"成都","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川B","city_id":904,"city_name":"绵阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川C","city_id":1076,"city_name":"自贡","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川D ","city_id":925,"city_name":"攀枝花","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川E","city_id":873,"city_name":"泸州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川F","city_id":772,"city_name":"德阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川H","city_id":800,"city_name":"广元","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川J","city_id":964,"city_name":"遂宁","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川K","city_id":917,"city_name":"内江","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川L","city_id":898,"city_name":"乐山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川M","city_id":1067,"city_name":"资阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川Q","city_id":1046,"city_name":"宜宾","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川R","city_id":910,"city_name":"南充","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川S","city_id":780,"city_name":"达州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川T","city_id":1060,"city_name":"雅安","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川U","city_id":719,"city_name":"阿坝","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川V","city_id":802,"city_name":"甘孜","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川W","city_id":891,"city_name":"凉山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川X","city_id":803,"city_name":"广安","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川Y","city_id":724,"city_name":"巴中","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"川Z","city_id":901,"city_name":"眉山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Sichuan","province":"四川"},{"citys":[{"carNoHeader":"桂A","city_id":915,"city_name":"南宁","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"桂B","city_id":892,"city_name":"柳州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"桂C","city_id":806,"city_name":"桂林","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"桂D","city_id":995,"city_name":"梧州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"桂E","city_id":728,"city_name":"北海","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"桂F","city_id":758,"city_name":"崇左","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"桂G","city_id":883,"city_name":"来宾","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"桂J","city_id":810,"city_name":"贺州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"桂K","city_id":1056,"city_name":"玉林","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"桂L","city_id":744,"city_name":"百色","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"桂M","city_id":818,"city_name":"河池","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"桂N","city_id":935,"city_name":"钦州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"桂P","city_id":789,"city_name":"防城港","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"桂R","city_id":804,"city_name":"贵港","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Guangxi","province":"广西"},{"citys":[{"carNoHeader":"浙A","city_id":819,"city_name":"杭州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"浙B","city_id":914,"city_name":"宁波","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"浙C","city_id":1007,"city_name":"温州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"浙D","city_id":947,"city_name":"绍兴","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"浙E","city_id":840,"city_name":"湖州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"浙F","city_id":858,"city_name":"嘉兴","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"浙G","city_id":847,"city_name":"金华","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"浙H","city_id":932,"city_name":"衢州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"浙J","city_id":988,"city_name":"台州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"浙K","city_id":897,"city_name":"丽水","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"浙L","city_id":1075,"city_name":"舟山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Zhejiang","province":"浙江"},{"citys":[{"carNoHeader":"云A","city_id":864,"city_name":"昆明","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"云C","city_id":1080,"city_name":"昭通","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"云D","city_id":931,"city_name":"曲靖","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"云E","city_id":766,"city_name":"楚雄","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"云F","city_id":1049,"city_name":"玉溪","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"云G","city_id":830,"city_name":"红河","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"云H","city_id":1005,"city_name":"文山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"云J","city_id":920,"city_name":"普洱","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"云K","city_id":1027,"city_name":"西双版纳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"云L","city_id":771,"city_name":"大理","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"云M","city_id":741,"city_name":"保山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"云N","city_id":773,"city_name":"德宏","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"云P","city_id":871,"city_name":"丽江","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"云Q","city_id":913,"city_name":"怒江","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"云R","city_id":777,"city_name":"迪庆","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"云S","city_id":881,"city_name":"临沧","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Yunnan","province":"云南"},{"citys":[{"carNoHeader":"蒙A ","city_id":827,"city_name":"呼和浩特","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"蒙B","city_id":739,"city_name":"包头","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"蒙C","city_id":1013,"city_name":"乌海","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"蒙D","city_id":767,"city_name":"赤峰","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"蒙E","city_id":825,"city_name":"呼伦贝尔","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"蒙F","city_id":1015,"city_name":"兴安","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"蒙G","city_id":979,"city_name":"通辽","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"蒙G","city_id":1032,"city_name":"锡林郭勒","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"蒙H","city_id":1012,"city_name":"乌兰察布","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"蒙K","city_id":737,"city_name":"巴彦淖尔","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"蒙K","city_id":786,"city_name":"鄂尔多斯","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"蒙L","city_id":716,"city_name":"阿拉善","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Inner Mongolia","province":"内蒙古"},{"citys":[{"carNoHeader":"辽A","city_id":962,"city_name":"沈阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"辽B","city_id":781,"city_name":"大连","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"辽C","city_id":723,"city_name":"鞍山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"辽D","city_id":788,"city_name":"抚顺","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"辽E","city_id":731,"city_name":"本溪","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"辽F","city_id":775,"city_name":"丹东","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"辽G","city_id":855,"city_name":"锦州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"辽H","city_id":1054,"city_name":"营口","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"辽J","city_id":795,"city_name":"阜新","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"辽K","city_id":874,"city_name":"辽阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"辽L","city_id":921,"city_name":"盘锦","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"辽M","city_id":983,"city_name":"铁岭","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"辽N","city_id":755,"city_name":"朝阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"辽P","city_id":833,"city_name":"葫芦岛","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Liaoning","province":"辽宁"},{"citys":[{"carNoHeader":"粤A","city_id":797,"city_name":"广州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤B","city_id":954,"city_name":"深圳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤C","city_id":1070,"city_name":"珠海","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤D","city_id":959,"city_name":"汕头","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤E","city_id":794,"city_name":"佛山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤F","city_id":967,"city_name":"韶关","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤G","city_id":1066,"city_name":"湛江","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤H","city_id":1074,"city_name":"肇庆","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤J","city_id":843,"city_name":"江门","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤K","city_id":903,"city_name":"茂名","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤L","city_id":831,"city_name":"惠州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤M","city_id":906,"city_name":"梅州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤N","city_id":975,"city_name":"汕尾","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤P","city_id":811,"city_name":"河源","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤Q","city_id":1044,"city_name":"阳江","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤R","city_id":934,"city_name":"清远","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤S","city_id":778,"city_name":"东莞","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤T","city_id":1077,"city_name":"中山","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤U","city_id":765,"city_name":"潮州","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤V","city_id":844,"city_name":"揭阳","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"粤W","city_id":1041,"city_name":"云浮","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Guangdong","province":"广东"},{"citys":[{"carNoHeader":"青A","city_id":1026,"city_name":"西宁","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"青B","city_id":839,"city_name":"海东","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"青C","city_id":809,"city_name":"海北","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"青D","city_id":813,"city_name":"黄南","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"青E","city_id":822,"city_name":"海南藏族","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"青F","city_id":801,"city_name":"果洛","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"青G","city_id":1052,"city_name":"玉树","engine":'false',"engine_length":0,"vin":'false',"vin_length":0},{"carNoHeader":"青H","city_id":838,"city_name":"海西","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Qinghai","province":"青海"},{"citys":[{"carNoHeader":"京","city_id":735,"city_name":"北京","engine":'false',"engine_length":0,"vin":'false',"vin_length":0}],"pinyin":"Beijing","province":"北京"}]},"message":"success"}
for citys in city_codes['data']['city']:
    for city_dict in citys['citys']:
        city_id = city_dict['city_id']
        city = city_dict['city_name']
        # city_no = city_dict['carNoHeader']
        print(city,city_id)
# Out:
# 济南 859
# 青岛 943
# 淄博 1063
# 枣庄 1068
# 东营 776
# 烟台 1050
# 潍坊 1010
# 济宁 862
# 泰安 977
# 威海 1001
# 日照 945
# 滨州 727
# 德州 782
# 聊城 900
# 临沂 890
# 菏泽 820
# 莱芜 886
# 台湾 2328
# 福州 792
# 莆田 927
# 泉州 929
# 厦门 1029
# 漳州 1071
# 龙岩 894
# 三明 950
# 南平 916
# 宁德 919
# 石家庄 952
# 唐山 982
# 秦皇岛 936
# 邯郸 832
# 邢台 1028
# 保定 745
# 张家口 1064
# 承德 748
# 沧州 754
# 廊坊 887
# 衡水 835
# 郑州 1073
# 开封 867
# 洛阳 895
# 平顶山 926
# 安阳 713
# 鹤壁 815
# 新乡 1019
# 焦作 854
# 濮阳 924
# 许昌 1031
# 漯河 872
# 三门峡 951
# 商丘 957
# 周口 1078
# 驻马店 1081
# 南阳 912
# 信阳 1024
# 济源 845
# 重庆 746
# 长沙 764
# 株洲 1062
# 湘潭 1018
# 衡阳 823
# 邵阳 958
# 岳阳 1053
# 张家界 1061
# 益阳 1039
# 常德 762
# 娄底 896
# 郴州 750
# 永州 1047
# 怀化 829
# 湘西 1033
# 武汉 1002
# 黄石 824
# 十堰 960
# 荆州 857
# 宜昌 1059
# 襄阳 1014
# 鄂州 785
# 荆门 849
# 黄冈 834
# 孝感 1022
# 咸宁 1030
# 仙桃 1016
# 潜江 933
# 神农架林区 961
# 恩施 787
# 天门 981
# 随州 974
# 海口 816
# 三亚 956
# 琼海 938
# 临高 899
# 万宁 1000
# 三沙 946
# 屯昌 990
# 文昌 996
# 澄迈 756
# 定安 779
# 琼中 941
# 乐东 884
# 五指山 1006
# 陵水 888
# 保亭 742
# 白沙 726
# 昌江 749
# 东方 774
# ...
