# %%
import requests
session = requests.session()
url_begin = 'https://jiage.autohome.com.cn/price/carlist/s-4851#pvareaid=3454446'
headers = {
    'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36',  
    "Upgrade-Insecure-Requests" : "1",
    "Referer" : "https://jiage.autohome.com.cn/price/carlist/s-4851",
}
def getProxy():
    # url = 'http://120.27.216.150:5000'
    url = 'http://192.168.2.120:5000'
    proxy = requests.get(url, auth=('admin', 'zd123456')).text[0:-6]
    return proxy
proxy = {'http': getProxy()}

response = session.get(url=url_begin, headers=headers, proxies=proxy)

# %%
index1_url = 'https://jiage.autohome.com.cn/price/carlist/p-43097-0-0-0-0-0-1-0#pvareaid=2094106'
index1_response = session.get(url=url_begin, headers=headers, proxies=proxy)
print(index1_response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta http-equiv='X-UA-Compatible' content='IE=edge,chrome=1'>
#   <meta name='renderer' content='webkit'>
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <meta http-equiv="X-UA-Compatible" content="ie=edge">
#   <meta name=”description” content=”你的描述内容”>
#   <meta name=”keyword” content=”关键字“>
#   <title>车主价格_奥迪Q5L_汽车之家</title>
#   <link rel="shortcut icon" href="//x.autoimg.cn/jiage/carprice/pc/img/bulebj32X32.ico"/>
#   <link rel='stylesheet' href='//s.autoimg.cn/jiage/pc/css/index.css'/>
#   <script type="text/javascript">
#
#     /*<![CDATA[*/
#     (function (M) {
# ...

# %%
if '暂无车主价格' in index1_response.text:
    print('没有请求成功')
else:
    print('~~~~~~~~~~~~~~~')
# Out:
# ~~~~~~~~~~~~~~~
